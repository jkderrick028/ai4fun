# %% [markdown]
# ## Train a CNN on MNIST using self-supervised learning

# %%
import numpy as np 
import torch, os, pickle, torchvision 
# import torchvision.transforms.v2 as transforms 
from torchvision import transforms 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
resultsPath = os.path.join('results', f'7_CNN_self_supervised')
if not os.path.exists(resultsPath):
    os.makedirs(resultsPath)

# %%
## defining hyperparameters 
learning_rate = 1e-2
batch_train = 64
batch_test = 1000 
n_epochs = 20
log_intervals = 100 

random_seed = 1
torch.manual_seed(random_seed)

if torch.cuda.is_available():
    device = 'cuda'
    print('GPU available')
else:
    device = 'cpu'
    print('only cpu available')
# Out:
# GPU available

# %%
## defining dataloader for training set 
data_train = torchvision.datasets.MNIST(
    root='data',
    download=False,
    train=True,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(
            mean=(0.1307,),
            std=(0.3081,)
        )
    ])
)
dataloader_train = torch.utils.data.DataLoader(data_train, batch_size=batch_train)

# %%
## defining dataloader for testing set 
data_test = torchvision.datasets.MNIST(
    root='data',
    download=False,
    train=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(
            mean=(0.1307,),
            std=(0.3081,)
        )
    ])
)
dataloader_test = torch.utils.data.DataLoader(data_test, batch_size=batch_test)

# %%
## visualizing example data 
example_data, example_label = next(iter(dataloader_train)) 
print(len(example_data))
print(len(example_label))
# Out:
# 64
# 64

# %%
plt.figure()

for i in np.arange(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(example_data[i].squeeze())
    plt.axis('off')
    plt.title(example_label[i])

plt.tight_layout()

# %%
example_data.shape
# Out:
# torch.Size([64, 1, 28, 28])

# %%
example_data_rotated = transforms.functional.rotate(example_data, angle=30, fill=-0.4242)

# %%
plt.figure()

for i in np.arange(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(example_data_rotated[i].squeeze())
    plt.axis('off')
    plt.title(example_label[i])

plt.tight_layout()

# %%
rotations = np.arange(0, 360, 90)

# %%
angles_random = np.random.choice(rotations, len(example_data), replace=True) 
angles_random
# Out:
# array([ 90,   0,   0,   0, 180, 270,   0,  90,   0, 270, 180, 180, 270,
#        270,   0,   0, 270,  90, 180,   0,   0, 270, 180,  90,  90,   0,
#         90,  90, 270,   0,  90, 180,  90, 180, 180,   0, 270,   0, 270,
#          0, 270, 270, 270, 180, 180,  90,   0, 270,  90, 180,  90, 270,
#        180, 270, 270, 270, 180,  90,   0, 180, 270, 180,  90,  90])

# %%
for i in np.arange(len(example_data)):
    example_data[i] = transforms.functional.rotate(example_data[i], angle=int(angles_random[i]), fill=-0.4242)

# %%
plt.figure()

for i in np.arange(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(example_data_rotated[i].squeeze())
    plt.axis('off')
    plt.title(example_label[i])

plt.tight_layout()

# %%
import torch.nn as nn 
import torch.nn.functional as F

# %%
class CNN_simple(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3)
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3) 
        self.maxpool2 = nn.MaxPool2d(kernel_size=2) 
        # original data:  1 x 28 x 28 
        # after conv1:    32 x 26 x 26
        # after maxpool1: 32 x 13 x 13
        # after conv2:    64 x 11 x 11
        # after maxpool2: 64 x 5 x 5
        self.dense1 = nn.Linear(in_features=64*5*5, out_features=128, bias=True)
        self.dense2 = nn.Linear(in_features=128, out_features=len(rotations), bias=True)

    def forward(self, x):
        output = F.relu(self.conv1(x)) 
        # print(output.shape)
        output = self.maxpool1(output)
        # print(output.shape)
        output = F.relu(self.conv2(output))
        # print(output.shape)
        output = self.maxpool2(output) 
        # print(output.shape)
        output = self.dense1(output.reshape(output.shape[0], -1))
        output = F.relu(output) 
        output = self.dense2(output)
        output = F.log_softmax(output)

        return output

# %%
cnn_simple = CNN_simple().to(device)
print(cnn_simple)
# Out:
# CNN_simple(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dense1): Linear(in_features=1600, out_features=128, bias=True)
#   (dense2): Linear(in_features=128, out_features=4, bias=True)
# )

# %%
example_output = cnn_simple(example_data_rotated.to(device))
# Out:
# /tmp/ipykernel_3342678/2458679285.py:28: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.log_softmax(output)

# %%
example_output.mean(axis=0)
# Out:
# tensor([-1.4190, -1.4578, -1.3896, -1.2891], device='cuda:0',
#        grad_fn=<MeanBackward1>)

# %%
optimizer = torch.optim.SGD(params=cnn_simple.parameters(), lr=learning_rate)

train_losses = []
test_losses = [] 
train_steps = [] 
test_steps = [len(dataloader_train.dataset)*i for i in np.arange(n_epochs+1)]
accuracy_rot = []

# %%
def train(epoch):
    cnn_simple.train()

    for batch_id, (data, label) in enumerate(dataloader_train):
        # first randomly rotate data images
        random_indx = np.random.choice(len(rotations), len(data), replace=True)
        random_angles = rotations[random_indx]
        random_angles = list(map(int, random_angles))
        for i in np.arange(len(data)):
            data[i] = transforms.functional.rotate(data[i], angle=random_angles[i], fill=-0.4242)

        data = data.to(device)
        optimizer.zero_grad() 
        output = cnn_simple(data) 
        loss = F.nll_loss(output, torch.tensor(random_indx).to(device))
        loss.backward()
        optimizer.step()

        if batch_id % log_intervals == 0:
            train_losses.append(loss.item()) 
            train_steps.append(batch_id * len(data) + epoch * len(dataloader_train.dataset)) 
            print(f'Training loss: epoch {epoch}, {batch_id * len(data)} / {len(dataloader_train.dataset)}, loss: {train_losses[-1]}')

# %%
def test():
    cnn_simple.eval() 
    test_loss = 0 
    correct_pred = 0 

    with torch.no_grad():
        for data, label in dataloader_test:
            # first randomly rotate data images 
            random_indx = np.random.choice(len(rotations), len(data), replace=True)
            random_angles = rotations[random_indx]
            random_angles = list(map(int, random_angles)) 
            for i in np.arange(len(data)):
                data[i] = transforms.functional.rotate(data[i], angle=random_angles[i], fill=-0.4242) 

            data = data.to(device)
            output = cnn_simple(data) 
            loss = F.nll_loss(output, torch.tensor(random_indx).to(device))
            test_loss += loss.item() 

            rot_predicted = torch.argmax(output, axis=1)
            correct_pred += (rot_predicted.detach().cpu() == torch.tensor(random_indx)).sum() 
        
        test_loss /= len(dataloader_test) 
        test_losses.append(test_loss) 
        accuracy_rot.append(correct_pred/len(dataloader_test.dataset))

    print(f'Test loss: {test_loss}, accuracy: {accuracy_rot[-1]}')

# %%
len(dataloader_test.dataset)
# Out:
# 10000

# %%
test()

for epoch in np.arange(1, n_epochs+1):
    train(epoch)
    test()
# Out:
# /tmp/ipykernel_3342678/2458679285.py:28: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F
# Training loss: epoch 5, 6400 / 60000, loss: 0.09243715554475784
# Training loss: epoch 5, 12800 / 60000, loss: 0.08217296004295349
# Training loss: epoch 5, 19200 / 60000, loss: 0.008985595777630806
# Training loss: epoch 5, 25600 / 60000, loss: 0.03297370672225952
# Training loss: epoch 5, 32000 / 60000, loss: 0.05292638763785362
# Training loss: epoch 5, 38400 / 60000, loss: 0.09730604290962219
# Training loss: epoch 5, 44800 / 60000, loss: 0.020992537960410118
# Training loss: epoch 5, 51200 / 60000, loss: 0.06670866906642914
# Training loss: epoch 5, 57600 / 60000, loss: 0.007976915687322617
# Test loss: 0.04387168362736702, accuracy: 0.98580002784729
# Training loss: epoch 6, 0 / 60000, loss: 0.03074502944946289
# Training loss: epoch 6, 6400 / 60000, loss: 0.12989819049835205
# Training loss: epoch 6, 12800 / 60000, loss: 0.026238316670060158
# Training loss: epoch 6, 19200 / 60000, loss: 0.013779299333691597
# Training loss: epoch 6, 25600 / 60000, loss: 0.017450522631406784
# Training loss: epoch 6, 32000 / 60000, loss: 0.06850089132785797
# Training loss: epoch 6, 38400 / 60000, loss: 0.09859028458595276
# Training loss: epoch 6, 44800 / 60000, loss: 0.010122230276465416
# Training loss: epoch 6, 51200 / 60000, loss: 0.057405564934015274
# Training loss: epoch 6, 57600 / 60000, loss: 0.01927122473716736
# Test loss: 0.05660532638430595, accuracy: 0.9797999858856201
# Training loss: epoch 7, 0 / 60000, loss: 0.04619767144322395
# Training loss: epoch 7, 6400 / 60000, loss: 0.08797388523817062
# Training loss: epoch 7, 12800 / 60000, loss: 0.03367247432470322
# Training loss: epoch 7, 19200 / 60000, loss: 0.003084486350417137
# Training loss: epoch 7, 25600 / 60000, loss: 0.009247850626707077
# Training loss: epoch 7, 32000 / 60000, loss: 0.041583575308322906
# Training loss: epoch 7, 38400 / 60000, loss: 0.10061858594417572
# Training loss: epoch 7, 44800 / 60000, loss: 0.018405426293611526
# Training loss: epoch 7, 51200 / 60000, loss: 0.029177701100707054
# Training loss: epoch 7, 57600 / 60000, loss: 0.004728822503238916
# Test loss: 0.05221082828938961, accuracy: 0.9815999865531921
# Training loss: epoch 8, 0 / 60000, loss: 0.06900905072689056
# Training loss: epoch 8, 6400 / 60000, loss: 0.040449101477861404
# Training loss: epoch 8, 12800 / 60000, loss: 0.019700931385159492
# Training loss: epoch 8, 19200 / 60000, loss: 0.010757073760032654
# Training loss: epoch 8, 25600 / 60000, loss: 0.03954937309026718
# Training loss: epoch 8, 32000 / 60000, loss: 0.016822654753923416
# Training loss: epoch 8, 38400 / 60000, loss: 0.07694439589977264
# Training loss: epoch 8, 44800 / 60000, loss: 0.008593646809458733
# Training loss: epoch 8, 51200 / 60000, loss: 0.07266592979431152
# Training loss: epoch 8, 57600 / 60000, loss: 0.00295014469884336
# Test loss: 0.046068933047354224, accuracy: 0.9833999872207642
# Training loss: epoch 9, 0 / 60000, loss: 0.06465079635381699
# Training loss: epoch 17, 0 / 60000, loss: 0.005466647911816835
# Training loss: epoch 17, 6400 / 60000, loss: 0.06645028293132782
# Training loss: epoch 17, 12800 / 60000, loss: 0.036993954330682755
# Training loss: epoch 17, 19200 / 60000, loss: 0.00857087504118681
# Training loss: epoch 17, 25600 / 60000, loss: 0.0043032122775912285
# Training loss: epoch 17, 32000 / 60000, loss: 0.0313030369579792
# Training loss: epoch 17, 38400 / 60000, loss: 0.07240534573793411
# Training loss: epoch 17, 44800 / 60000, loss: 0.011022320948541164
# Training loss: epoch 17, 51200 / 60000, loss: 0.03428449109196663
# Training loss: epoch 17, 57600 / 60000, loss: 0.002355502685531974
# Test loss: 0.02212266717106104, accuracy: 0.9919000267982483
# Training loss: epoch 18, 0 / 60000, loss: 0.030476948246359825
# Training loss: epoch 18, 6400 / 60000, loss: 0.038537364453077316
# Training loss: epoch 18, 12800 / 60000, loss: 0.008363120257854462
# Training loss: epoch 18, 19200 / 60000, loss: 0.0024826563894748688
# Training loss: epoch 18, 25600 / 60000, loss: 0.003344988450407982
# Training loss: epoch 18, 32000 / 60000, loss: 0.027302682399749756
# Training loss: epoch 18, 38400 / 60000, loss: 0.021696776151657104
# Training loss: epoch 18, 44800 / 60000, loss: 0.008098200894892216
# Training loss: epoch 18, 51200 / 60000, loss: 0.018819758668541908
# Training loss: epoch 18, 57600 / 60000, loss: 0.0011755586601793766
# Test loss: 0.01957700392231345, accuracy: 0.9936000108718872
# Training loss: epoch 19, 0 / 60000, loss: 0.008626910857856274
# Training loss: epoch 19, 6400 / 60000, loss: 0.04334288835525513
# Training loss: epoch 19, 12800 / 60000, loss: 0.00823611207306385
# Training loss: epoch 19, 19200 / 60000, loss: 0.0010456494055688381
# Training loss: epoch 19, 25600 / 60000, loss: 0.004616891499608755
# Training loss: epoch 19, 32000 / 60000, loss: 0.017797669395804405
# Training loss: epoch 19, 38400 / 60000, loss: 0.0352618545293808
# Training loss: epoch 19, 44800 / 60000, loss: 0.0039956714026629925
# Training loss: epoch 19, 51200 / 60000, loss: 0.004446047358214855
# Training loss: epoch 19, 57600 / 60000, loss: 0.0006959889433346689
# Test loss: 0.019995434768497945, accuracy: 0.9926000237464905
# Training loss: epoch 20, 0 / 60000, loss: 0.0028784542810171843
# Training loss: epoch 20, 6400 / 60000, loss: 0.02310813218355179
# Training loss: epoch 20, 12800 / 60000, loss: 0.03236092999577522
# Training loss: epoch 20, 19200 / 60000, loss: 0.000449253071565181
# Training loss: epoch 20, 25600 / 60000, loss: 0.0026611159555613995
# Training loss: epoch 20, 32000 / 60000, loss: 0.031061893329024315
# Training loss: epoch 20, 38400 / 60000, loss: 0.027179110795259476
# Training loss: epoch 20, 44800 / 60000, loss: 0.006970630493015051
# Training loss: epoch 20, 51200 / 60000, loss: 0.043328747153282166
# Training loss: epoch 20, 57600 / 60000, loss: 0.00016696045349817723
# Test loss: 0.021015640068799257, accuracy: 0.9926000237464905

# %%
plt.figure()

plt.plot(train_steps, train_losses)
plt.plot(test_steps, test_losses)
plt.legend(['train', 'test'])

# %%
plt.figure()

plt.plot(test_steps, accuracy_rot)
plt.legend('accuracy')
plt.title('pred rotation accuracy')
# Out:
# Text(0.5, 1.0, 'pred rotation accuracy')

# %%
# saving currently trained model state
torch.save(cnn_simple.state_dict(), os.path.join(resultsPath, 'cnn_simple.pth'))
torch.save(optimizer.state_dict(), os.path.join(resultsPath, 'optimizer.pth'))

# %%
# remove the current dense layer, which is used to predict rotation angle
# create a new dense layer to predict accuracy. freeze the trained parameters 
cnn_simple.dense2 = nn.Linear(in_features=128, out_features=10, bias=True)
for param in cnn_simple.parameters():
    param.requires_grad = False
for param in cnn_simple.dense2.parameters():
    param.requires_grad = True

# %%
cnn_simple = cnn_simple.to(device)

# %%
len(dataloader_train.dataset)
# Out:
# 60000

# %%
# training the last layer on limied amount of data 
dataloader_fine_tune_train = torch.utils.data.DataLoader(torch.utils.data.Subset(data_train, np.arange(2000)), batch_size=4, shuffle=True)
dataloader_fine_tune_test = torch.utils.data.DataLoader(torch.utils.data.Subset(data_test, np.arange(2000)), batch_size=5, shuffle=True)

# %%
len(dataloader_fine_tune_test)
# Out:
# 400

# %%
n_epochs = 20
optimizer = torch.optim.SGD(params=cnn_simple.parameters(), lr=learning_rate)

# %%
train_losses = []
test_losses = [] 
train_steps = [] 
test_steps = [len(dataloader_fine_tune_train.dataset)*i for i in np.arange(n_epochs+1)]
accuracies = []

# %%
def train(epoch):
    cnn_simple.train()

    for batch_id, (data, label) in enumerate(dataloader_fine_tune_train):
        data, label = data.to(device), label.to(device)        
        optimizer.zero_grad() 
        output = cnn_simple(data) 
        loss = F.nll_loss(output, label)
        loss.backward()
        optimizer.step()

        if batch_id % log_intervals == 0:
            train_losses.append(loss.item()) 
            train_steps.append(batch_id * len(data) + epoch * len(dataloader_fine_tune_train.dataset)) 
            print(f'Training loss: epoch {epoch}, {batch_id * len(data)} / {len(dataloader_fine_tune_train.dataset)}, loss: {train_losses[-1]}')

# %%
def test():
    cnn_simple.eval() 
    test_loss = 0 
    correct_pred = 0 

    with torch.no_grad():
        for data, label in dataloader_fine_tune_test:
            output = cnn_simple(data.to(device)) 
            loss = F.nll_loss(output, label.to(device))
            test_loss += loss.item() 

            label_predicted = torch.argmax(output.detach().cpu(), axis=1)
            correct_pred += (label_predicted == label).sum()
        
        test_loss /= len(dataloader_fine_tune_test) 
        test_losses.append(test_loss) 
        accuracies.append(correct_pred/len(dataloader_fine_tune_test.dataset))

    print(f'Test loss: {test_loss}, accuracy: {accuracies[-1]}')

# %%
test()

for epoch in np.arange(1, n_epochs+1):
    train(epoch)
    test()
# Out:
# /tmp/ipykernel_3342678/2458679285.py:28: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.log_softmax(output)
# Test loss: 3.287805008292198, accuracy: 0.08550000190734863
# Training loss: epoch 1, 0 / 2000, loss: 3.1379029750823975
# Training loss: epoch 1, 400 / 2000, loss: 0.7522396445274353
# Training loss: epoch 1, 800 / 2000, loss: 1.8563631772994995
# Training loss: epoch 1, 1200 / 2000, loss: 1.4746946096420288
# Training loss: epoch 1, 1600 / 2000, loss: 0.4744863510131836
# Test loss: 0.6947444130480289, accuracy: 0.7870000004768372
# Training loss: epoch 2, 0 / 2000, loss: 0.06877105683088303
# Training loss: epoch 2, 400 / 2000, loss: 0.26721620559692383
# Training loss: epoch 2, 800 / 2000, loss: 1.1410974264144897
# Training loss: epoch 2, 1200 / 2000, loss: 0.1331990361213684
# Training loss: epoch 2, 1600 / 2000, loss: 0.3580551743507385
# Test loss: 0.6378028568439186, accuracy: 0.7929999828338623
# Training loss: epoch 3, 0 / 2000, loss: 0.1382998824119568
# Training loss: epoch 3, 400 / 2000, loss: 0.6565316915512085
# Training loss: epoch 3, 800 / 2000, loss: 0.057724058628082275
# Training loss: epoch 3, 1200 / 2000, loss: 0.18640054762363434
# Training loss: epoch 3, 1600 / 2000, loss: 0.10552822053432465
# Test loss: 0.5826434398954734, accuracy: 0.8140000104904175
# Training loss: epoch 4, 0 / 2000, loss: 0.14970800280570984
# Training loss: epoch 4, 400 / 2000, loss: 0.37658563256263733
# Training loss: epoch 4, 800 / 2000, loss: 0.04333775117993355
# Training loss: epoch 4, 1200 / 2000, loss: 0.04458509758114815
# Training loss: epoch 4, 1600 / 2000, loss: 1.066532015800476
# Test loss: 0.4999158737785183, accuracy: 0.8349999785423279
# Training loss: epoch 5, 0 / 2000, loss: 0.1441480815410614
# Training loss: epoch 5, 400 / 2000, loss: 0.10004834085702896
# Training loss: epoch 5, 800 / 2000, loss: 0.0030298323836177588
# Training loss: epoch 5, 1200 / 2000, loss: 1.3029776811599731
# Training loss: epoch 5, 1600 / 2000, loss: 0.3702850341796875
# Test loss: 0.5297703119623475, accuracy: 0.8199999928474426
# Training loss: epoch 6, 0 / 2000, loss: 1.9641635417938232
# Training loss: epoch 6, 400 / 2000, loss: 0.495683878660202
# Training loss: epoch 6, 800 / 2000, loss: 0.18948501348495483
# Training loss: epoch 6, 1200 / 2000, loss: 0.7758803963661194
# Training loss: epoch 6, 1600 / 2000, loss: 0.12546306848526
# Test loss: 0.5675488474639132, accuracy: 0.8080000281333923
# Training loss: epoch 7, 0 / 2000, loss: 0.008252842351794243
# Training loss: epoch 7, 400 / 2000, loss: 0.030896268784999847
# Training loss: epoch 7, 800 / 2000, loss: 0.25502341985702515
# Training loss: epoch 7, 1200 / 2000, loss: 0.41280239820480347
# Training loss: epoch 7, 1600 / 2000, loss: 0.09832826256752014
# Test loss: 0.4599039705051109, accuracy: 0.8535000085830688
# Training loss: epoch 8, 0 / 2000, loss: 1.1382346153259277
# Training loss: epoch 8, 400 / 2000, loss: 0.3437582552433014
# Training loss: epoch 8, 800 / 2000, loss: 0.17878083884716034
# Training loss: epoch 8, 1200 / 2000, loss: 1.3983341455459595
# Training loss: epoch 8, 1600 / 2000, loss: 0.16752341389656067
# Test loss: 0.4592249012459069, accuracy: 0.8525000214576721
# Training loss: epoch 9, 0 / 2000, loss: 0.05195628106594086
# Training loss: epoch 9, 400 / 2000, loss: 0.05812312662601471
# Training loss: epoch 9, 800 / 2000, loss: 0.30857500433921814
# Training loss: epoch 9, 1200 / 2000, loss: 0.43404620885849
# Training loss: epoch 9, 1600 / 2000, loss: 0.19944116473197937
# Test loss: 0.4186476766411215, accuracy: 0.8679999709129333
# Training loss: epoch 10, 0 / 2000, loss: 0.5218403935432434
# Training loss: epoch 10, 400 / 2000, loss: 0.15677452087402344
# Training loss: epoch 10, 800 / 2000, loss: 0.08072303235530853
# Training loss: epoch 10, 1200 / 2000, loss: 0.09678056836128235
# Training loss: epoch 10, 1600 / 2000, loss: 0.04361511021852493
# Test loss: 0.4349926507216878, accuracy: 0.8544999957084656
# Training loss: epoch 11, 0 / 2000, loss: 0.47895631194114685
# Training loss: epoch 11, 400 / 2000, loss: 0.19974595308303833
# Training loss: epoch 11, 800 / 2000, loss: 0.06461363285779953
# Training loss: epoch 11, 1200 / 2000, loss: 0.7881382703781128
# Training loss: epoch 11, 1600 / 2000, loss: 0.7250362038612366
# Test loss: 0.4878106839762768, accuracy: 0.8454999923706055
# Training loss: epoch 12, 0 / 2000, loss: 0.21138477325439453
# Training loss: epoch 12, 400 / 2000, loss: 0.15513287484645844
# Training loss: epoch 12, 800 / 2000, loss: 0.10811230540275574
# Training loss: epoch 12, 1200 / 2000, loss: 0.1395794153213501
# Training loss: epoch 12, 1600 / 2000, loss: 0.5240628123283386
# Test loss: 0.43792236468871126, accuracy: 0.8510000109672546
# Training loss: epoch 13, 0 / 2000, loss: 0.4567025303840637
# Training loss: epoch 13, 400 / 2000, loss: 0.013490244746208191
# Training loss: epoch 13, 800 / 2000, loss: 0.4545994699001312
# Training loss: epoch 13, 1200 / 2000, loss: 0.4261258542537689
# Training loss: epoch 13, 1600 / 2000, loss: 0.33922258019447327
# Test loss: 0.39958224156987854, accuracy: 0.8665000200271606
# Training loss: epoch 14, 0 / 2000, loss: 0.057776451110839844
# Training loss: epoch 14, 400 / 2000, loss: 0.12369577586650848
# Training loss: epoch 14, 800 / 2000, loss: 0.06093122810125351
# Training loss: epoch 14, 1200 / 2000, loss: 0.05335644632577896
# Training loss: epoch 14, 1600 / 2000, loss: 0.1022348701953888
# Test loss: 0.3827743526920676, accuracy: 0.8790000081062317
# Training loss: epoch 15, 0 / 2000, loss: 0.4422023892402649
# Training loss: epoch 15, 400 / 2000, loss: 0.3663743734359741
# Training loss: epoch 15, 800 / 2000, loss: 0.3422280251979828
# Training loss: epoch 15, 1200 / 2000, loss: 0.16575999557971954
# Training loss: epoch 15, 1600 / 2000, loss: 0.016344213858246803
# Test loss: 0.39049367323168555, accuracy: 0.875
# Training loss: epoch 16, 0 / 2000, loss: 0.3364890515804291
# Training loss: epoch 16, 400 / 2000, loss: 0.0037964980583637953
# Training loss: epoch 16, 800 / 2000, loss: 0.28463542461395264
# Training loss: epoch 16, 1200 / 2000, loss: 0.1698279231786728
# Training loss: epoch 16, 1600 / 2000, loss: 0.1195373684167862
# Test loss: 0.42579005836858413, accuracy: 0.8525000214576721
# Training loss: epoch 17, 0 / 2000, loss: 0.30713486671447754
# Training loss: epoch 17, 400 / 2000, loss: 0.0261765718460083
# Training loss: epoch 17, 800 / 2000, loss: 0.28633764386177063
# Training loss: epoch 17, 1200 / 2000, loss: 0.1197238564491272
# Training loss: epoch 17, 1600 / 2000, loss: 0.16051563620567322
# Test loss: 0.37471700433059596, accuracy: 0.8794999718666077
# Training loss: epoch 18, 0 / 2000, loss: 0.25821924209594727
# Training loss: epoch 18, 400 / 2000, loss: 0.020752711221575737
# Training loss: epoch 18, 800 / 2000, loss: 0.0764121413230896
# Training loss: epoch 18, 1200 / 2000, loss: 0.11932698637247086
# Training loss: epoch 18, 1600 / 2000, loss: 0.007619417272508144
# Test loss: 0.37185975884087386, accuracy: 0.8849999904632568
# Training loss: epoch 19, 0 / 2000, loss: 0.006429821252822876
# Training loss: epoch 19, 400 / 2000, loss: 0.12244970351457596
# Training loss: epoch 19, 800 / 2000, loss: 0.16646866500377655
# Training loss: epoch 19, 1200 / 2000, loss: 0.0008193000103347003
# Training loss: epoch 19, 1600 / 2000, loss: 0.2333250194787979
# Test loss: 0.3635326042916859, accuracy: 0.8820000290870667
# Training loss: epoch 20, 0 / 2000, loss: 0.040844548493623734
# Training loss: epoch 20, 400 / 2000, loss: 0.050158314406871796
# Training loss: epoch 20, 800 / 2000, loss: 0.6291987299919128
# Training loss: epoch 20, 1200 / 2000, loss: 0.3128179907798767
# Training loss: epoch 20, 1600 / 2000, loss: 0.0225258506834507
# Test loss: 0.38726788039901294, accuracy: 0.8740000128746033

# %%
plt.figure()

plt.plot(train_steps, train_losses)
plt.plot(test_steps, test_losses)
plt.legend(['train', 'test'])

# %%
plt.figure()

plt.plot(test_steps, accuracies)
plt.legend('accuracy')

# %%
counter = 0

for name, param in cnn_simple.named_parameters():
    print(name)
    print(param.requires_grad)
# Out:
# conv1.weight
# False
# conv1.bias
# False
# conv2.weight
# False
# conv2.bias
# False
# dense1.weight
# False
# dense1.bias
# False
# dense2.weight
# True
# dense2.bias
# True

# %%
example_data, example_label = next(iter(dataloader_train)) 
example_output = cnn_simple(example_data.to(device)) 
predicted_labels = example_output.argmax(axis=1).detach().cpu()
# Out:
# /tmp/ipykernel_3342678/2458679285.py:28: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.log_softmax(output)

# %%
for i in np.arange(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(example_data[i].squeeze())
    plt.title(f'act: {example_label[i]}, pred: {predicted_labels[i]}')
    plt.axis('off')

plt.tight_layout()

# %%
# saving currently trained model state
torch.save(cnn_simple.state_dict(), os.path.join(resultsPath, 'cnn_simple_fine_tuned.pth'))
torch.save(optimizer.state_dict(), os.path.join(resultsPath, 'optimizer_fined_tuned.pth'))
